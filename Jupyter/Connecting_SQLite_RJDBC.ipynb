# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0103ENSkillsNetwork23619267-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center> <font size = 6>Hands-on Lab: Accessing Your Database using RJDBC</font></h1>

# %% [markdown]
# ### Welcome!
#
# In this hands-on lab, we will discover how to connect and query data from database servers with R using RJDBC.

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <h3>Tasks</h3>
# <ol><ol><ol>
# <li><a href="https://#refa">Load the RJDBC library</a></li>
# <li><a href="https://#refb">Provide database credentials</a></li>
# <li><a href="https://#refc">Connect to the database</a></li>
# <li><a href="https://#refd">Execute a Query (and retrieve results)</a></li>
# <li><a href="https://#refe">Dis-connect</a></li>
# </ol></ol></ol>
# <p></p>
# Estimated Time Needed: <strong>10 min</strong>
# </div>

# %% [markdown]
# **Pre-requisite**: In this lab we will use Jupyter Notebooks within SN Labs to access data in a SQLite  using RJDBC.

# %% [markdown]
# ### a. Load the RJDBC library
#
# The RJDBC package is pre-installed in SN Labs. Let’s load the RJDBC package by clicking on the following cell and executing it (Shift+Enter):

# %%
library(RJDBC);

# %% [markdown]
# ### b. Download the SQLite Database and SQLite JDBC jar files.
#
# *   In the following cell we will be loading the **curl** package.
# *   We will then use the **curl_download**  function to download the SQLITE **Instructors**  database and the **SQLITE JDBC** jar file.
#
# "

# %%
library(curl)

# %%
curl_download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/datasets/Instructors.db","Instructors.db")

# %%
curl_download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0103EN-SkillsNetwork/jars/sqlite-jdbc-3.27.2.1.jar","sqlite-jdbc-3.27.2.1.jar")

# %% [markdown]
# ### c. Provide database Driver class details
#
# In the following cell enter the SQLITE jdbc driver class details which will be used  for connecting to **SQLite**

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# Load the related SQLite JDBC driver class in a variable called **dsn_driver**.
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# #Enter the values for you database connection
# dsn_driver = "org.sqlite.JDBC"
#
# ```
#
# </details>

# %% [markdown]
# ### d. Connect to the database
#
# First we will specify which database driver to use. Then create a JDBC connection string.

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# Create a jdbc connection string containing the Driver class and  class path of the jar file and save it in a variable called **jcc**.
#
# Next create another connection string to load the SQLite database and save it in a variable called **jdbc_path**.
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# jcc = JDBC(dsn_driver, "sqlite-jdbc-3.27.2.1.jar");
# jdbc_path = paste("jdbc:sqlite:Instructors.db");
# ```
#
# </details>

# %% [markdown]
# Now, let's use the driver and connection string to actually connect to the database using the RJDBC function dbConnect().

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# Connect to the database by providing the connection strings related to driver class and loading of SQLite database and save it in a variable called **conn**.
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# conn = dbConnect(jcc, jdbc_path)
# ```
#
# </details>

# %% [markdown]
# ### e. Execute a Query (and return the results)
#
# Next, execute a query against the SQLIte system catalog table **sqlite_master** and fetch the results into a R dataframe.

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# ```
# Fill in the ...
# query = "SELECT * FROM ...";
# rs = dbSendQuery(...);
# df = fetch(...);
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# query = "SELECT name FROM  sqlite_master"
# rs = dbSendQuery(conn, query);
# df = fetch(rs, -1);
# ```
#
# </details>

# %% [markdown]
# Let’s examine the contents of the dataframe by looking at the first few rows:

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# ```
# # Fill in the ...
# head(...)
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# head(df)
# ```
#
# </details>

# %% [markdown]
# <a id="refd"></a>
#
# ### f. Execute a Query (and return the results)
#
# Next, execute a query against the **SQLITE** user defined  table **Instructor** and fetch the results into a R dataframe.

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# ```
# Fill in the ...
# query = "SELECT * FROM ...";
# rs = dbSendQuery(...);
# df = fetch(...);
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# query = "SELECT * FROM Instructor;"
# rs = dbSendQuery(conn, query);
# df = fetch(rs, -1);
# ```
#
# </details>

# %% [markdown]
# <a id="refe"></a>
#
# ### g. Dis-connect
#
# Finally, as a best practice we should close the database connection once we're done with it.

# %% [markdown]
# <details>
# <summary>Click here to view/hide hint</summary>
# <p>
#
# Use the function which closes the connection and frees resources
#
# </details>

# %% [markdown]
# <details>
# <summary>Click here to view/hide solution</summary>
# <p>
#
# ```
# dbDisconnect(conn)
# ```
#
# </details>

# %% [markdown]
# <a id="ref4g"></a>
#
# ### Summary
#
# In this lab you accessed data in a SQLIte database using RJDBC connection from a R notebook in Jupyter, and fetched the results of a query for analysis in a R dataframe.

# %% [markdown]
# <HR>

# %% [markdown]
# #### Thank you for completing this lab on getting connected and querying databases using RJDBC.

# %% [markdown]
# <hr>
#
# ## Authors
#
# *   [Lakshmi Holla](https://www.linkedin.com/in/lakshmi-holla-b39062149/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0103ENSkillsNetwork23619267-2022-01-01)
#
# ## Changelog
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description                              |
# | ----------------- | ------- | ------------- | ----------------------------------------------- |
# | 2022-03-16        | 1.0     | Lakshmi Holla | Created Initial Version using SQLite with RJDBC |
#
# <hr>
#
# <h2 align=center><font size = 5>Copyright &copy; IBM Corporation 2021-2022. All rights reserved.</h2>
